# %% [markdown]
# ### Importando as bibliotecas

# %%
import pandas as pd
import numpy as np
from arcgis.features import GeoAccessor, GeoSeriesAccessor
import fuzzywuzzy

# %% [markdown]
# ### Abrindo os dados de ruas da prefeitura

# %%
ruas_prefeitura = pd.DataFrame.spatial.from_featureclass("ruas_prefeitura_nbl")
ruas_prefeitura[['lg_tipo','lg_nome']].drop_duplicates(keep='first').to_csv(r"D:\Trabalho\faculdade\TCC\outputs\preprocessamento\georreferenciamento\classeviaria_prefeitura.csv")
ruas_prefeitura
# Out:
#         OBJECTID  ...                                              SHAPE
# 0              1  ...  {"paths": [[[340737.7692999998, 7390143.2261],...
# 1              2  ...  {"paths": [[[325401.3393000001, 7404855.9624],...
# 2              3  ...  {"paths": [[[341219.89940000046, 7397215.6892]...
# 3              4  ...  {"paths": [[[333620.8459999999, 7404427.6303],...
# 4              5  ...  {"paths": [[[329586.4269000003, 7388972.0354],...
# ...          ...  ...                                                ...
# 225992    225993  ...  {"paths": [[[329878.21740000043, 7390590.0372]...
# 225993    225994  ...  {"paths": [[[329885.7697999999, 7390619.9728],...
# 225994    225995  ...  {"paths": [[[329576.7549999999, 7390685.974], ...
# 225995    225996  ...  {"paths": [[[329623.3233000003, 7390718.6988],...
# 225996    225997  ...  {"paths": [[[329771.4782999996, 7390818.7626],...
#
# [225997 rows x 17 columns]

# %%
# Out:
#        lg_tipo                                  lg_nome
# 0            R                              GAMA BARROS
# 1            R              DEZOITO (J. PAULISTANO-JAR)
# 2           AV                           AIRTON PRETINI
# 3            R                                    HORTO
# 4
# ...        ...                                      ...
# 225975      AV                 ATLANTICA (VILA JARAGUA)
# 225976       R            ENEAS CARNEIRO (VILA JARAGUA)
# 225978      PC                  JOAO INACIO DE OLIVEIRA
# 225981      PC                 ANTONIO ALONSO GUTIERREZ
# 225984       R  ANTONIO PACHECO VALENTE (PROLONGAMENTO)
#
# [54210 rows x 2 columns]

# %% [markdown]
# ### Abrindo os dados de ruas da CET

# %%
lentidao_cet = pd.read_csv(r"D:\Trabalho\faculdade\TCC\dados\lentidao\baixados\lentidaotrechos2019.csv",sep=';',encoding='latin-1')

# %% [markdown]
# Criando DataFrame com os nomes (únicos) dos corredores

# %%
corredores_lentidao_cet = pd.DataFrame(lentidao_cet["corredor"].unique()).rename(columns={0:'corredor'})
corredores_lentidao_cet['corredor'] = corredores_lentidao_cet['corredor'].str.strip(' ')
corredores_lentidao_cet.to_csv(r"D:\Trabalho\faculdade\TCC\outputs\preprocessamento\georreferenciamento\corredores_lentidao.csv")

# %% [markdown]
# ## Fazendo Fuzzy Join

# %% [markdown]
# ### Lentidão com ruas da CET

# %% [markdown]
# Criando função que faz o Fuzzy Join

# %%
from fuzzywuzzy import process

def fuzzy_merge(df_1, df_2, key1, key2, threshold=60, limit=3):
    """
    :param df_1: the left table to join
    :param df_2: the right table to join
    :param key1: key column of the left table
    :param key2: key column of the right table
    :param threshold: how close the matches should be to return a match, based on Levenshtein distance
    :param limit: the amount of matches that will get returned, these are sorted high to low
    :return: dataframe with boths keys and matches
    """
    s = df_2[key2].tolist()
    
    m = df_1[key1].apply(lambda x: process.extract(x, s, limit=limit))    
    df_1['matches'] = m
    
    m2 = df_1['matches'].apply(lambda x: ', '.join([i[0] for i in x if i[1] >= threshold]))
    df_1['matches'] = m2
    
    return df_1,m

# %% [markdown]
# Fazendo join dos corredores (lentidão CET) com as vias do Dataset de ruas da CET

# %% [markdown]
# #### Considerando coluna "cvc_nmlogr"

# %%
#Análise feita considerando apenas o nome "puro" da rua. Ou seja, sem prefixos como Av, R. Etc.
fuzzy_merge,limiares = fuzzy_merge(corredores_lentidao_cet,ruas_cet,"corredor","lg_nome")

# %%
fuzzy_merge.head(10)
# Out:
#                                    corredor                                            matches
# 0  Marginal Pinheiros                        MARGINAL DO RIO PINHEIROS, MARGINAL PINHEIROS ...
# 1  Marginal Tietê                                  MAR, MARGINAL TIETE ASCB EXPRESSA, MARGINAL
# 2  Radial Leste - DEC MO                     PONTA DE LESTE, LESTE-OESTE, ELLIS MAAS (MO S ...
# 3  Salim Farah Maluf, Av/Tatuapé, Pte        SALIM FARAH MALUF, SALIM FARAH MALUF, SALIM FA...
# 4  Limão / Av. Ordem e Progresso, Pte        ORDEM E PROGRESSO, ORDEM E PROGRESSO, ORDEM E ...
# 5  Anchieta, Via                                                  ANCHIETA, ANCHIETA, ANCHIETA
# 6  Cruzeiro do Sul, Pt e Av                             CRUZEIRO DO SUL, CRUZEIRO DO SUL, CRUZ
# 7  Marginal Tietê - Pista Central                                  CENTRAL, MARGINAL, MARGINAL
# 8  Radial Leste - DEC BR                             PONTA DE LESTE, LESTE-OESTE, JARDIM LESTE
# 9  Vale/P.Maia/Tirad/S.Dumont                                                 VALE, VALE, VALE

# %%
#Criando colunas que contém os nomes de ruas que deram match
match1_lista, match2_lista, match3_lista = [],[],[]
for matches_trio in fuzzy_merge['matches']:
    match1,match2,match3 = matches_trio.split(', ')[0],matches_trio.split(', ')[1],matches_trio.split(', ')[2]
    match1_lista.append(match1)
    match2_lista.append(match2)
    match3_lista.append(match3)

#Criando colunas que contém os graus de similaridade de cada rua
limiar1_lista,limiar2_lista,limiar3_lista = [],[],[]
for linha in limiares:
    for i, item in enumerate(linha):
        if i==0:
            limiar1_lista.append(item[1])
        elif i==1:
            limiar2_lista.append(item[1])
        elif i==2:
            limiar3_lista.append(item[1])
            
#Criando um DataFrame com todas essas colunas           
similaridade_lentidao_e_CET = pd.DataFrame({'corredor':cet_corredores['corredor'],'match 1': match1_lista, 'match 2': match2_lista,'match 3': match3_lista,
              'similaridade 1': limiar1_lista,'similaridade 2': limiar2_lista,'similaridade 3': limiar3_lista} )

# %%
similaridade_lentidao_e_CET.to_csv(r"D:\Trabalho\faculdade\TCC\outputs\preprocessamento\georreferenciamento\similaridade_lentidao_e_CET.csv",index=False)

# %% [markdown]
# #### Considerando coluna cvc_nomelg

# %%
fuzzy_merge,limiares = fuzzy_merge(corredores_lentidao_cet,ruas_cet,"corredor","cvc_nomelg")

# %%
fuzzy_merge.head(30)
# Out:
#                                     corredor                                            matches
# 0   Marginal Pinheiros                        AV   MARGINAL PINHEIROS, AV   MARGINAL PINHEIR...
